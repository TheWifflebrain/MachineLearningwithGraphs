# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
datasets = ["EN","DE","ES","FR","PT","RU","Large"]
t = ["T-Kmeans", "P-Kmeans", "N2V K-Means", "GraRep K-Means", "SC", "Greedy Mod", "Louvain", "GNNS100","GNNS2500"]
tm = ["Method", "EN","DE","ES","FR","PT","RU","Large"]

# %%
EN_times = [65.83, 117.98, 161.91, 210.22, 236.91, 149.36, 1.40, 1.30, 30.58]
DE_times =[92.60 , 152.85 , 442.94 , 373.92 , 355.99 , 608.96 , 3.79 , 1.68 , 26.43]
ES_times =[57.26 , 72.82 , 159.50, 149.02 , 152.05 , 116.88 , 1.30 , 0.95 , 13.09]
FR_times =[73.18 , 123.71 , 300.58 , 239.18 , 199.38 , 224.17 , 2.55 , 1.20 , 14.96]
PT_times =[38.15, 65.55 , 87.71 , 73.15 , 70.82 , 18.32 , 0.61 , 0.47 , 4.53]
RU_times =[52.64 , 75.94 , 138.05 , 141.83 , 127.15 , 69.28 , 0.93 , 0.75 , 12.28]
Large_times =[0 , 0 , 0 ,0 , 0 , 0 , 308.58 , 93.21 , 1640.08]
lists_times = [EN_times, DE_times, ES_times, FR_times, PT_times, RU_times, Large_times]

# %%
T_Kmeans_times = [l[0] for l in lists_times]
P_Kmeans_times = [l[1] for l in lists_times] 
N2V_K_Means_times = [l[2] for l in lists_times] 
GraRep_K_Means_times = [l[3] for l in lists_times] 
SC_times = [l[4] for l in lists_times] 
Greedy_Mod_times = [l[5] for l in lists_times] 
Louvain_times = [l[6] for l in lists_times] 
GNNS100_times = [l[7] for l in lists_times]
GNNS2500_times = [l[8] for l in lists_times]

T_Kmeans_times.insert(0, t[0])
P_Kmeans_times.insert(0, t[1])
N2V_K_Means_times.insert(0, t[2])
GraRep_K_Means_times.insert(0, t[3])
SC_times.insert(0, t[4])
Greedy_Mod_times.insert(0, t[5])
Louvain_times.insert(0, t[6])
GNNS100_times.insert(0, t[7])
GNNS2500_times.insert(0, t[8])

print(T_Kmeans_times)
# Out:
# ['T-Kmeans', 65.83, 92.6, 57.26, 73.18, 38.15, 52.64, 0]

# %%
df = pd.DataFrame([T_Kmeans_times, P_Kmeans_times, N2V_K_Means_times, GraRep_K_Means_times, SC_times, Greedy_Mod_times, Louvain_times, GNNS100_times, GNNS2500_times],
                  columns=tm)
print(df)
ax = df.plot(x='Method', kind='bar',stacked=False,title='Time in Seconds for Each Dataset For Each Method', ylim=(0,625), yticks=(np.arange(0, 650, 50)))
ax.set_ylabel("Time in Seconds")
ax.grid('on', axis='y')
# Out:
#            Method      EN      DE      ES      FR     PT      RU    Large
# 0        T-Kmeans   65.83   92.60   57.26   73.18  38.15   52.64     0.00
# 1        P-Kmeans  117.98  152.85   72.82  123.71  65.55   75.94     0.00
# 2     N2V K-Means  161.91  442.94  159.50  300.58  87.71  138.05     0.00
# 3  GraRep K-Means  210.22  373.92  149.02  239.18  73.15  141.83     0.00
# 4              SC  236.91  355.99  152.05  199.38  70.82  127.15     0.00
# 5      Greedy Mod  149.36  608.96  116.88  224.17  18.32   69.28     0.00
# 6         Louvain    1.40    3.79    1.30    2.55   0.61    0.93   308.58
# 7         GNNS100    1.30    1.68    0.95    1.20   0.47    0.75    93.21
# 8        GNNS2500   30.58   26.43   13.09   14.96   4.53   12.28  1640.08

# %%
EN_mod = [0.00809 , 0.03026 , 0.00207 , 0.07723 , 0.13562 , 0.41973 , 0.45028 , 0.45521 , 0.47033]
DE_mod = [1.11e-16 , 0.02906 , 0.00130 , 0.04101 , 0.47643 , 0.23464 , 0.29133 , 0.29724 , 0.29843]
ES_mod = [0.0 , 0.29609 , 0.00148 , 0.15250 , 0.36507 , 0.36986 , 0.39293 , 0.40895 , 0.41242]
FR_mod = [0.00376 , 0.01228 , 0.00081 , 0.09231 , 0.22192 , 0.30251 , 0.34234 , 0.34700 , 0.35099]
PT_mod = [0.0 , 0.02574 , 0.00288 , 0.04910 , 0.05445 , 0.26367 , 0.28772 , 0.29465 , 0.29780]
RU_mod = [0.01164 , 0.00726 , 0.00275 , 0.07572 , 0.23955 , 0.29239 , 0.34111 , 0.34358 , 0.34830]
Large_mod = [0 , 0 , 0 , 0 , 0 , 0 , 0.41667 , 0.42297 , 0.42493]
lists_mod = [EN_mod, DE_mod, ES_mod, FR_mod, PT_mod, RU_mod, Large_mod]

# %%
T_Kmeans_mod = [l[0] for l in lists_mod]
P_Kmeans_mod = [l[1] for l in lists_mod] 
N2V_K_Means_mod = [l[2] for l in lists_mod] 
GraRep_K_Means_mod = [l[3] for l in lists_mod] 
SC_mod = [l[4] for l in lists_mod] 
Greedy_Mod_mod = [l[5] for l in lists_mod] 
Louvain_mod = [l[6] for l in lists_mod] 
GNNS100_mod = [l[7] for l in lists_mod]
GNNS2500_mod = [l[8] for l in lists_mod]

T_Kmeans_mod.insert(0, t[0])
P_Kmeans_mod.insert(0, t[1])
N2V_K_Means_mod.insert(0, t[2])
GraRep_K_Means_mod.insert(0, t[3])
SC_mod.insert(0, t[4])
Greedy_Mod_mod.insert(0, t[5])
Louvain_mod.insert(0, t[6])
GNNS100_mod.insert(0, t[7])
GNNS2500_mod.insert(0, t[8])

print(T_Kmeans_mod)
# Out:
# ['T-Kmeans', 0.00809, 1.11e-16, 0.0, 0.00376, 0.0, 0.01164, 0]

# %%
df1 = pd.DataFrame([T_Kmeans_mod, P_Kmeans_mod, N2V_K_Means_mod, GraRep_K_Means_mod, SC_mod, Greedy_Mod_mod, Louvain_mod, GNNS100_mod, GNNS2500_mod],
                  columns=tm)
print(df1)
ax1 = df1.plot(x='Method', kind='bar',stacked=False,title='Modularity for Each Dataset For Each Method', ylim=(0,.55), yticks=(np.arange(0, 1, .05)))
ax1.set_ylabel("Modularity")
ax1.grid('on', axis='y')
# Out:
#            Method       EN            DE       ES       FR       PT       RU  \
# 0        T-Kmeans  0.00809  1.110000e-16  0.00000  0.00376  0.00000  0.01164
# 1        P-Kmeans  0.03026  2.906000e-02  0.29609  0.01228  0.02574  0.00726
# 2     N2V K-Means  0.00207  1.300000e-03  0.00148  0.00081  0.00288  0.00275
# 3  GraRep K-Means  0.07723  4.101000e-02  0.15250  0.09231  0.04910  0.07572
# 4              SC  0.13562  4.764300e-01  0.36507  0.22192  0.05445  0.23955
# 5      Greedy Mod  0.41973  2.346400e-01  0.36986  0.30251  0.26367  0.29239
# 6         Louvain  0.45028  2.913300e-01  0.39293  0.34234  0.28772  0.34111
# 7         GNNS100  0.45521  2.972400e-01  0.40895  0.34700  0.29465  0.34358
# 8        GNNS2500  0.47033  2.984300e-01  0.41242  0.35099  0.29780  0.34830
#
#      Large
# 0  0.00000
# 1  0.00000
# 2  0.00000
# 3  0.00000
# 4  0.00000
# 5  0.00000
# 6  0.41667
# 7  0.42297
# 8  0.42493

# %%
EN_com = [3 , 4 , 3 , 16 , 9 , 104 , 20 , 21 , 21]
DE_com = [1 , 2 , 16 , 2 , 17 , 69 , 10 , 11 , 11]
ES_com = [1 , 2 , 48 , 4 , 16 , 39 , 12 , 12 , 12]
FR_com = [3 , 5 , 2 , 5 , 21 , 23 , 7 , 8 , 8]
PT_com = [1 , 2 , 85 , 3 , 25 , 20 , 7 , 8 , 8]
RU_com = [3 , 12 , 2 , 5 , 28 , 56 , 11 , 13 , 13]
Large_com = [0 , 0 , 0 , 0 , 0 , 0 , 21 , 20 , 20]
lists_com = [EN_com, DE_com, ES_com, FR_com, PT_com, RU_com, Large_com]

# %%
T_Kmeans_com = [l[0] for l in lists_com]
P_Kmeans_com = [l[1] for l in lists_com] 
N2V_K_Means_com = [l[2] for l in lists_com] 
GraRep_K_Means_com = [l[3] for l in lists_com] 
SC_com = [l[4] for l in lists_com] 
Greedy_Mod_com = [l[5] for l in lists_com] 
Louvain_com = [l[6] for l in lists_com] 
GNNS100_com = [l[7] for l in lists_com]
GNNS2500_com= [l[8] for l in lists_com]

T_Kmeans_com.insert(0, t[0])
P_Kmeans_com.insert(0, t[1])
N2V_K_Means_com.insert(0, t[2])
GraRep_K_Means_com.insert(0, t[3])
SC_com.insert(0, t[4])
Greedy_Mod_com.insert(0, t[5])
Louvain_com.insert(0, t[6])
GNNS100_com.insert(0, t[7])
GNNS2500_com.insert(0, t[8])

print(T_Kmeans_com)
# Out:
# ['T-Kmeans', 3, 1, 1, 3, 1, 3, 0]

# %%
df2 = pd.DataFrame([T_Kmeans_com, P_Kmeans_com, N2V_K_Means_com, GraRep_K_Means_com, SC_com, Greedy_Mod_com, Louvain_com, GNNS100_com, GNNS2500_com],
                  columns=tm)
print(df2)
ax2 = df2.plot(x='Method', kind='bar',stacked=False,title='Number of Communities for Each Dataset For Each Method', ylim=(0,87), yticks=(np.arange(0, 100, 5)))
ax2.set_ylabel("Number of Communities")
ax2.grid('on', axis='y')
# Out:
#            Method   EN  DE  ES  FR  PT  RU  Large
# 0        T-Kmeans    3   1   1   3   1   3      0
# 1        P-Kmeans    4   2   2   5   2  12      0
# 2     N2V K-Means    3  16  48   2  85   2      0
# 3  GraRep K-Means   16   2   4   5   3   5      0
# 4              SC    9  17  16  21  25  28      0
# 5      Greedy Mod  104  69  39  23  20  56      0
# 6         Louvain   20  10  12   7   7  11     21
# 7         GNNS100   21  11  12   8   8  13     20
# 8        GNNS2500   21  11  12   8   8  13     20
