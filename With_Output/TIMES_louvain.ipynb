# %%
import networkx as nx
import networkx.algorithms.community as nx_comm
import pandas as pd
import numpy as np
import time
from networkx.algorithms.community import greedy_modularity_communities

# %%
df7 = pd.read_csv('../twitch_gamers/large_twitch_edges.csv')
df1 = pd.read_csv('../twitch/DE/musae_DE_edges.csv')
df2 = pd.read_csv('../twitch/ENGB/musae_ENGB_edges.csv')
df3 = pd.read_csv('../twitch/ES/musae_ES_edges.csv')
df4 = pd.read_csv('../twitch/FR/musae_FR_edges.csv')
df5 = pd.read_csv('../twitch/PTBR/musae_PTBR_edges.csv')
df6 = pd.read_csv('../twitch/RU/musae_RU_edges.csv')

# %%
GS = []


nodes = []
edges = []
for x, y in zip(df1['from'], df1['to']):
    nodes.append(x)
    nodes.append(y)
    temp_tup = (x, y)
    edges.append(temp_tup)
nodes = set(nodes)
G = nx.Graph()
G.add_nodes_from(nodes)
G.add_edges_from(edges)
print(len(nodes))
print(len(edges))
nx.write_gexf(G, "test1.gexf")
GS.append(G)


nodes = []
edges = []
for x, y in zip(df2['from'], df2['to']):
    nodes.append(x)
    nodes.append(y)
    temp_tup = (x, y)
    edges.append(temp_tup)
nodes = set(nodes)
G2 = nx.Graph()
G2.add_nodes_from(nodes)
G2.add_edges_from(edges)
print(len(nodes))
print(len(edges))
nx.write_gexf(G2, "test2.gexf")
GS.append(G2)


nodes = []
edges = []
# change here
for x, y in zip(df3['from'], df3['to']):
    nodes.append(x)
    nodes.append(y)
    temp_tup = (x, y)
    edges.append(temp_tup)
nodes = set(nodes)
G3 = nx.Graph()
G3.add_nodes_from(nodes)
G3.add_edges_from(edges)
print(len(nodes))
print(len(edges))
nx.write_gexf(G3, "test3.gexf")
GS.append(G3)


nodes = []
edges = []
for x, y in zip(df4['from'], df4['to']):
    nodes.append(x)
    nodes.append(y)
    temp_tup = (x, y)
    edges.append(temp_tup)
nodes = set(nodes)
G4 = nx.Graph()
G4.add_nodes_from(nodes)
G4.add_edges_from(edges)
print(len(nodes))
print(len(edges))
nx.write_gexf(G4, "test4.gexf")
GS.append(G4)


nodes = []
edges = []
for x, y in zip(df5['from'], df5['to']):
    nodes.append(x)
    nodes.append(y)
    temp_tup = (x, y)
    edges.append(temp_tup)
nodes = set(nodes)
G5 = nx.Graph()
G5.add_nodes_from(nodes)
G5.add_edges_from(edges)
print(len(nodes))
print(len(edges))
nx.write_gexf(G5, "test4.gexf")
GS.append(G5)

nodes = []
edges = []
for x, y in zip(df6['from'], df6['to']):
    nodes.append(x)
    nodes.append(y)
    temp_tup = (x, y)
    edges.append(temp_tup)
nodes = set(nodes)
G6 = nx.Graph()
G6.add_nodes_from(nodes)
G6.add_edges_from(edges)
print(len(nodes))
print(len(edges))
nx.write_gexf(G6, "test4.gexf")
GS.append(G6)


nodes = []
edges = []
for x, y in zip(df7['numeric_id_1'], df7['numeric_id_2']):
    nodes.append(x)
    nodes.append(y)
    temp_tup = (x, y)
    edges.append(temp_tup)
nodes = set(nodes)
G7 = nx.Graph()
G7.add_nodes_from(nodes)
G7.add_edges_from(edges)
print(len(nodes))
print(len(edges))
nx.write_gexf(G7, "test4.gexf")
GS.append(G7)

print(GS[0])
print(GS[1]) 
print(GS[2])
print(GS[3])
print(GS[4])
print(GS[5])
print(GS[6])
# Out:
# 9498
# 153138
# 7126
# 35324
# 4648
# 59382
# 6549
# 112666
# 1912
# 31299
# 4385
# 37304
# 168114
# 6797557
# Graph with 9498 nodes and 153138 edges
# Graph with 7126 nodes and 35324 edges
# Graph with 4648 nodes and 59382 edges
# Graph with 6549 nodes and 112666 edges
# Graph with 1912 nodes and 31299 edges
# Graph with 4385 nodes and 37304 edges
# Graph with 168114 nodes and 6797557 edges

# %% [markdown]
# Louvain Comm

# %%
for g in GS:
    start_time = time.time()
    louvain = nx_comm.louvain_communities(g)
    num_communities = len(louvain)
    size_community = [len(c) for c in louvain]
    print("--- %s seconds ---" % (time.time() - start_time))
    print(num_communities)
    print(size_community)
    print(np.sum(size_community))

    l_mod = nx_comm.modularity(g, louvain)
    print('modularity:',l_mod)
    print('\n\n')
# Out:
# --- 3.768031358718872 seconds ---
# 10
# [20, 731, 381, 943, 2266, 1706, 1265, 1978, 201, 7]
# 9498
# modularity: 0.29133288283908115
#
#
#
# --- 1.403998613357544 seconds ---
# 20
# [896, 3, 870, 99, 92, 1047, 385, 5, 451, 142, 79, 764, 405, 633, 3, 859, 101, 74, 5, 213]
# 7126
# modularity: 0.4502806395386508
#
#
#
# --- 1.3045437335968018 seconds ---
# 12
# [2, 1710, 7, 143, 8, 11, 53, 2, 982, 205, 1522, 3]
# 4648
# modularity: 0.3929279710303338
#
#
#
# --- 2.5485143661499023 seconds ---
# 7
# [19, 451, 399, 1369, 1524, 1420, 1367]
# 6549
# modularity: 0.34234057745344487
#
#
#
# --- 0.6059982776641846 seconds ---
# 7
# [22, 392, 96, 231, 255, 570, 346]
# 1912
# modularity: 0.28772357552705896
#
#
#
# --- 0.9335927963256836 seconds ---
# 11
# [776, 602, 4, 340, 727, 267, 52, 350, 99, 353, 815]
# 4385
# modularity: 0.34111439491890677
#
#
#
# --- 308.58440375328064 seconds ---
# 21
# ...

# %% [markdown]
# greedy_modularity_communities

# %%
# take like 90 secs
for count, g in enumerate(GS):
    if(count == 6): break
    start_time = time.time()
    gm = greedy_modularity_communities(g)

    print("--- %s seconds ---" % (time.time() - start_time))
    
    num_communities = len(gm)
    size_community = [len(c) for c in gm]
    print(num_communities)
    print(size_community)

    gm_mod = nx_comm.modularity(g, gm)
    print('modularity:',gm_mod)
    print('\n\n')
# Out:
# --- 608.9648413658142 seconds ---
# 69
# [4159, 2686, 2167, 86, 73, 65, 24, 15, 10, 10, 8, 8, 7, 7, 7, 6, 6, 5, 5, 5, 5, 5, 5, 5, 4, 4, 4, 4, 4, 4, 4, 4, 4, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2]
# modularity: 0.23464524708113
#
#
#
# --- 149.3554584980011 seconds ---
# 104
# [2243, 1725, 1365, 524, 380, 236, 144, 90, 59, 49, 24, 14, 10, 9, 8, 7, 6, 6, 5, 5, 5, 5, 4, 4, 4, 4, 4, 4, 4, 4, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2]
# modularity: 0.41973190779947195
#
#
#
# --- 116.87564873695374 seconds ---
# 39
# [2221, 1718, 345, 179, 24, 19, 18, 9, 8, 8, 7, 7, 6, 6, 6, 5, 5, 4, 4, 4, 4, 3, 3, 3, 3, 3, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2]
# modularity: 0.3698575678471678
#
#
#
# --- 224.1664366722107 seconds ---
# 23
# ...
